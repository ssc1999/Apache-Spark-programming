# %% [markdown]
# -sandbox
#
# <div style="text-align: center; line-height: 0; padding-top: 9px;">
#   <img src="https://databricks.com/wp-content/uploads/2018/03/db-academy-rgb-1200px.png" alt="Databricks Learning" style="width: 600px">
# </div>

# %% [markdown]
# # Complex Types
#
# Explore built-in functions for working with collections and strings.
#
# ##### Objectives
# 1. Apply collection functions to process arrays
# 1. Union DataFrames together
#
# ##### Methods
# - <a href="https://spark.apache.org/docs/latest/api/python/reference/pyspark.sql/dataframe.html" target="_blank">DataFrame</a>:**`union`**, **`unionByName`**
# - <a href="https://spark.apache.org/docs/latest/api/python/reference/pyspark.sql/functions.html" target="_blank">Built-In Functions</a>:
#   - Aggregate: **`collect_set`**
#   - Collection: **`array_contains`**, **`element_at`**, **`explode`**
#   - String: **`split`**

# %%
# %run ../Includes/Classroom-Setup
# Out:
# Python interpreter will be restarted.
# Python interpreter will be restarted.
# Skipping install of existing datasets to "dbfs:/mnt/dbacademy-datasets/apache-spark-programming-with-databricks/v03"
#
# Validating the locally installed datasets...(4 seconds)
#
# Predefined tables in "da_sergio_salgado_4613_asp":
#   -none-
#
# Predefined paths variables:
#   DA.paths.user_db:     dbfs:/mnt/dbacademy-users/sergio.salgado@n.world/apache-spark-programming-with-databricks/database.db
#   DA.paths.datasets:    dbfs:/mnt/dbacademy-datasets/apache-spark-programming-with-databricks/v03
#   DA.paths.working_dir: dbfs:/mnt/dbacademy-users/sergio.salgado@n.world/apache-spark-programming-with-databricks
#   DA.paths.checkpoints: dbfs:/mnt/dbacademy-users/sergio.salgado@n.world/apache-spark-programming-with-databricks/_checkpoints
#   DA.paths.sales:       dbfs:/mnt/dbacademy-datasets/apache-spark-programming-with-databricks/v03/ecommerce/sales/sales.delta
#   DA.paths.users:       dbfs:/mnt/dbacademy-datasets/apache-spark-programming-with-databricks/v03/ecommerce/users/users.delta
#   DA.paths.events:      dbfs:/mnt/dbacademy-datasets/apache-spark-programming-with-databricks/v03/ecommerce/events/events.delta
#   DA.paths.products:    dbfs:/mnt/dbacademy-datasets/apache-spark-programming-with-databricks/v03/products/products.delta
#
# Setup completed in 5 seconds

# %%
from pyspark.sql.functions import *

# %%
df = spark.read.format("delta").load(DA.paths.sales)

display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_id</th><th>email</th><th>transaction_timestamp</th><th>total_item_quantity</th><th>purchase_revenue_in_usd</th><th>unique_items</th><th>items</th></tr></thead><tbody><tr><td>257437</td><td>kmunoz@powell-duran.com</td><td>1592194221828900</td><td>1</td><td>1995.0</td><td>1</td><td>List(List(null, M_PREM_K, Premium King Mattress, 1995.0, 1995.0, 1))</td></tr><tr><td>282611</td><td>bmurillo@hotmail.com</td><td>1592504237604072</td><td>1</td><td>940.5</td><td>1</td><td>List(List(NEWBED10, M_STAN_Q, Standard Queen Mattress, 940.5, 1045.0, 1))</td></tr><tr><td>257448</td><td>bradley74@gmail.com</td><td>1592200438030141</td><td>1</td><td>945.0</td><td>1</td><td>List(List(null, M_STAN_F, Standard Full Mattress, 945.0, 945.0, 1))</td></tr><tr><td>257440</td><td>jameshardin@campbell-morris.biz</td><td>1592197217716495</td><td>1</td><td>1045.0</td><td>1</td><td>List(List(null, M_STAN_Q, Standard Queen Mattress, 1045.0, 1045.0, 1))</td></tr><tr><td>283949</td><td>whardin@hotmail.com</td><td>1592510720760323</td><td>1</td><td>535.5</td><td>1</td><td>List(List(NEWBED10, M_STAN_T, Standard Twin Mattress, 535.5, 595.0, 1))</td></tr><tr><td>257444</td><td>emily88@cobb.com</td><td>1592199040703476</td><td>1</td><td>1045.0</td><td>1</td><td>List(List(null, M_STAN_Q, Standard Queen Mattress, 1045.0, 1045.0, 1))</td></tr><tr><td>257449</td><td>craig61@luna-oliver.com</td><td>1592200459769596</td><td>1</td><td>1195.0</td><td>1</td><td>List(List(null, M_STAN_K, Standard King Mattress, 1195.0, 1195.0, 1))</td></tr><tr><td>257441</td><td>johnsonashley@mcclain.com</td><td>1592197729873798</td><td>1</td><td>945.0</td><td>1</td><td>List(List(null, M_STAN_F, Standard Full Mattress, 945.0, 945.0, 1))</td></tr><tr><td>264191</td><td>maxwelltara@edwards.com</td><td>1592306255847870</td><td>2</td><td>993.6</td><td>2</td><td>List(List(NEWBED10, M_STAN_Q, Standard Queen Mattress, 940.5, 1045.0, 1), List(NEWBED10, P_FOAM_S, Standard Foam Pillow, 53.1, 59.0, 1))</td></tr><tr><td>286727</td><td>rojasjorge@yahoo.com</td><td>1592533048926949</td><td>1</td><td>535.5</td><td>1</td><td>List(List(NEWBED10, M_STAN_T, Standard Twin Mattress, 535.5, 595.0, 1))</td></tr><tr><td>287573</td><td>marmstrong46@hotmail.com</td><td>1592547727220317</td><td>1</td><td>53.1</td><td>1</td><td>List(List(NEWBED10, P_FOAM_S, Standard Foam Pillow, 53.1, 59.0, 1))</td></tr><tr><td>257462</td><td>ndavis79@yahoo.com</td><td>1592204258037615</td><td>1</td><td>595.0</td><td>1</td><td>List(List(null, M_STAN_T, Standard Twin Mattress, 595.0, 595.0, 1))</td></tr><tr><td>257458</td><td>xadams@salazar.com</td><td>1592203707959868</td><td>1</td><td>1095.0</td><td>1</td><td>List(List(null, M_PREM_T, Premium Twin Mattress, 1095.0, 1095.0, 1))</td></tr><tr><td>257464</td><td>chadjones@williams.com</td><td>1592204292754623</td><td>2</td><td>2390.0</td><td>2</td><td>List(List(null, M_PREM_Q, Premium Queen Mattress, 1795.0, 1795.0, 1), List(null, M_STAN_T, Standard Twin Mattress, 595.0, 595.0, 1))</td></tr><tr><td>271597</td><td>johnsonderrick@yahoo.com</td><td>1592399808941985</td><td>5</td><td>2846.7</td><td>5</td><td>List(List(NEWBED10, M_STAN_K, Standard King Mattress, 1075.5, 1195.0, 1), List(NEWBED10, P_DOWN_K, King Down Pillow, 143.1, 159.0, 1), List(NEWBED10, M_STAN_T, Standard Twin Mattress, 535.5, 595.0, 1), List(NEWBED10, M_PREM_T, Premium Twin Mattress, 985.5, 1095.0, 1), List(NEWBED10, P_DOWN_S, Standard Down Pillow, 107.10000000000001, 119.0, 1))</td></tr><tr><td>257500</td><td>chavezbenjamin@byrd.com</td><td>1592208672234813</td><td>1</td><td>1045.0</td><td>1</td><td>List(List(null, M_STAN_Q, Standard Queen Mattress, 1045.0, 1045.0, 1))</td></tr><tr><td>278696</td><td>ericzimmerman@valentine.com</td><td>1592477039776439</td><td>1</td><td>850.5</td><td>1</td><td>List(List(NEWBED10, M_STAN_F, Standard Full Mattress, 850.5, 945.0, 1))</td></tr><tr><td>284289</td><td>gtra ...

# %%
# You will need this DataFrame for a later exercise
details_df = (df
              .withColumn("items", explode("items"))
              .select("email", "items.item_name")
              .withColumn("details", split(col("item_name"), " "))
             )
display(details_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>email</th><th>item_name</th><th>details</th></tr></thead><tbody><tr><td>phillipmorgan@hotmail.com</td><td>Standard Queen Mattress</td><td>List(Standard, Queen, Mattress)</td></tr><tr><td>derekreed@yahoo.com</td><td>Standard Twin Mattress</td><td>List(Standard, Twin, Mattress)</td></tr><tr><td>jamespowell@gmail.com</td><td>King Foam Pillow</td><td>List(King, Foam, Pillow)</td></tr><tr><td>wbrown@gonzales-miranda.com</td><td>Standard Twin Mattress</td><td>List(Standard, Twin, Mattress)</td></tr><tr><td>zavalamario@yahoo.com</td><td>Standard Twin Mattress</td><td>List(Standard, Twin, Mattress)</td></tr><tr><td>meganhopkins@gmail.com</td><td>Standard Queen Mattress</td><td>List(Standard, Queen, Mattress)</td></tr><tr><td>meganhopkins@gmail.com</td><td>King Foam Pillow</td><td>List(King, Foam, Pillow)</td></tr><tr><td>daniel054@gmail.com</td><td>Standard King Mattress</td><td>List(Standard, King, Mattress)</td></tr><tr><td>hoffmanjohn@chan.com</td><td>Standard King Mattress</td><td>List(Standard, King, Mattress)</td></tr><tr><td>anthony1587@yahoo.com</td><td>Standard Full Mattress</td><td>List(Standard, Full, Mattress)</td></tr><tr><td>camerontorres@gmail.com</td><td>Standard Queen Mattress</td><td>List(Standard, Queen, Mattress)</td></tr><tr><td>camerontorres@gmail.com</td><td>Standard Twin Mattress</td><td>List(Standard, Twin, Mattress)</td></tr><tr><td>nicholsjamie@yahoo.com</td><td>Standard King Mattress</td><td>List(Standard, King, Mattress)</td></tr><tr><td>emma43@yahoo.com</td><td>Premium Full Mattress</td><td>List(Premium, Full, Mattress)</td></tr><tr><td>emma43@yahoo.com</td><td>Standard Foam Pillow</td><td>List(Standard, Foam, Pillow)</td></tr><tr><td>emma43@yahoo.com</td><td>Standard Queen Mattress</td><td>List(Standard, Queen, Mattress)</td></tr><tr><td>josephburke@wilson-brooks.com</td><td>Standard Twin Mattress</td><td>List(Standard, Twin, Mattress)</td></tr><tr><td>victor63@gmail.com</td><td>Premium Full Mattress</td><td>List(Premium, Full, Mattress)</td></tr><tr><td>victor63@gmail.com</td><td>Standard Twin Mattress</td><td>List(Standard, Twin, Mattress)</td></tr><tr><td>campbellkatrina@phillips-duarte.com</td><td>Standard Full Mattress</td><td>List(Standard, Full, Mattress)</td></tr><tr><td>pennyjimenez@patel-jennings.com</td><td>Standard Twin Mattress</td><td>List(Standard, Twin, Mattress)</td></tr><tr><td>omichael@gmail.com</td><td>Standard King Mattress</td><td>List(Standard, King, Mattress)</td></tr><tr><td>nelsonsara@yahoo.com</td><td>Standard Queen Mattress</td><td>List(Standard, Queen, Mattress)</td></tr><tr><td>kristinwolfe@gmail.com</td><td>Standard Full Mattress</td><td>List(Standard, Full, Mattress)</td></tr><tr><td>kimberly85@beck.com</td><td>Standard King Mattress</td><td>List(Standard, King, Mattress)</td></tr><tr><td>jonesbruce@coleman.com</td><td>Standard Foam Pillow</td><td>List(Standard, Foam, Pillow)</td></tr><tr><td>jennifer93@mooney-stafford.com</td><td>Standard Queen Mattress</td><td>List(Standard, Queen, Mattress)</td></tr><tr><td>ericksondesiree@yahoo.com</td><td>Standard Twin Mattress</td><td>List(Standard, Twin, Mattress)</td></tr><tr><td>victoranderson@yahoo.com</td><td>Premium King Mattress</td><td>List(Premium, King, Mattress)</td></tr><tr><td>anthony03@yahoo.com</td><td>Standard Full Mattress</td><td>List(Standard, Full, Mattress)</td></tr><tr><td>michael37@burke.com</td><td>Standard King Mattress</td><td>List(Standard, King, Mattress)</td></tr><tr><td>chelsea99@yahoo.com</td><td>Premium Queen Mattress</td><td>List(Premium, Queen, Mattress)</td></tr><tr><td>xfrederick@wilson-conley.net</td><td>Standard Twin Mattress</td><td>List(Standard, Twin, Mattress)</td></tr><tr><td>rpeterson65@hotmail.com</td><td>Premium Twin Mattress</td><td>List(Premium, Twin, Mattress)</td></tr><tr><td>philip59@yahoo.com</td><td>Standard Twin Mattress</td><td>List(Standard, Twin, Mattress)</td> ...

# %% [markdown]
# ### String Functions
# Here are some of the built-in functions available for manipulating strings.
#
# | Method | Description |
# | --- | --- |
# | translate | Translate any character in the src by a character in replaceString |
# | regexp_replace | Replace all substrings of the specified string value that match regexp with rep |
# | regexp_extract | Extract a specific group matched by a Java regex, from the specified string column |
# | ltrim | Removes the leading space characters from the specified string column |
# | lower | Converts a string column to lowercase |
# | split | Splits str around matches of the given pattern |

# %% [markdown]
# For example: let's imagine that we need to parse our **`email`** column. We're going to use the **`split`** function  to split domain and handle.

# %%
from pyspark.sql.functions import split

# %%
display(df.select(split(df.email, '@', 0).alias('email_handle')))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>email_handle</th></tr></thead><tbody><tr><td>List(kmunoz, powell-duran.com)</td></tr><tr><td>List(bmurillo, hotmail.com)</td></tr><tr><td>List(bradley74, gmail.com)</td></tr><tr><td>List(jameshardin, campbell-morris.biz)</td></tr><tr><td>List(whardin, hotmail.com)</td></tr><tr><td>List(emily88, cobb.com)</td></tr><tr><td>List(craig61, luna-oliver.com)</td></tr><tr><td>List(johnsonashley, mcclain.com)</td></tr><tr><td>List(maxwelltara, edwards.com)</td></tr><tr><td>List(rojasjorge, yahoo.com)</td></tr><tr><td>List(marmstrong46, hotmail.com)</td></tr><tr><td>List(ndavis79, yahoo.com)</td></tr><tr><td>List(xadams, salazar.com)</td></tr><tr><td>List(chadjones, williams.com)</td></tr><tr><td>List(johnsonderrick, yahoo.com)</td></tr><tr><td>List(chavezbenjamin, byrd.com)</td></tr><tr><td>List(ericzimmerman, valentine.com)</td></tr><tr><td>List(gtravis, sosa.com)</td></tr><tr><td>List(austin10, robinson-burton.com)</td></tr><tr><td>List(wilsonteresa, walsh.net)</td></tr><tr><td>List(hilljoshua43, hotmail.com)</td></tr><tr><td>List(gcummings, mullins-smith.com)</td></tr><tr><td>List(ashleylevy, gonzalez.com)</td></tr><tr><td>List(jwilson, gmail.com)</td></tr><tr><td>List(gayala, phillips.net)</td></tr><tr><td>List(john1545, hotmail.com)</td></tr><tr><td>List(annagray, kaufman.com)</td></tr><tr><td>List(doylechristina, lopez.info)</td></tr><tr><td>List(amy7022, gmail.com)</td></tr><tr><td>List(darren48, lucas-hayes.net)</td></tr><tr><td>List(kbennett, gmail.com)</td></tr><tr><td>List(tammyroth, gmail.com)</td></tr><tr><td>List(bennettzachary88, gmail.com)</td></tr><tr><td>List(andrew5297, hotmail.com)</td></tr><tr><td>List(barryandrew, roy-gonzalez.com)</td></tr><tr><td>List(brittany447, yahoo.com)</td></tr><tr><td>List(marieperez, yahoo.com)</td></tr><tr><td>List(awilson, gmail.com)</td></tr><tr><td>List(timothy72, roman-francis.info)</td></tr><tr><td>List(tracigarcia, hotmail.com)</td></tr><tr><td>List(stephenwilliams, pena.net)</td></tr><tr><td>List(cjohnson, burgess-martin.biz)</td></tr><tr><td>List(evankrause, yahoo.com)</td></tr><tr><td>List(owerner, yahoo.com)</td></tr><tr><td>List(njordan, yahoo.com)</td></tr><tr><td>List(smithmarvin, moran-gonzalez.biz)</td></tr><tr><td>List(yschwartz, gmail.com)</td></tr><tr><td>List(oacevedo, hotmail.com)</td></tr><tr><td>List(efowler, vaughan-vance.com)</td></tr><tr><td>List(racheljackson, gmail.com)</td></tr><tr><td>List(aliciaarias, washington.org)</td></tr><tr><td>List(robertjacobs, hotmail.com)</td></tr><tr><td>List(lreynolds, allison.com)</td></tr><tr><td>List(chaveznatalie, hotmail.com)</td></tr><tr><td>List(lewisjoseph, gmail.com)</td></tr><tr><td>List(johnoliver, phelps.biz)</td></tr><tr><td>List(dstout, keith.net)</td></tr><tr><td>List(mahoneykristi, hotmail.com)</td></tr><tr><td>List(epittman, miller.com)</td></tr><tr><td>List(sandrapatterson, hotmail.com)</td></tr><tr><td>List(christopher69, gutierrez-flores.info)</td></tr><tr><td>List(aprillee, mendez.com)</td></tr><tr><td>List(palmerjonathan, washington.com)</td></tr><tr><td>List(andersonamy, hawkins.net)</td></tr><tr><td>List(maddenelizabeth, morgan.net)</td></tr><tr><td>List(onealcory, hotmail.com)</td></tr><tr><td>List(glopez, figueroa.net)</td></tr><tr><td>List(chadcolon, ramirez.com)</td></tr><tr><td>List(troyturner, gmail.com)</td></tr><tr><td>List(jeffrey62, hotmail.com)</td></tr><tr><td>List(flandry, giles.org)</td></tr><tr><td>List(rebecca8267, hotmail.com)</td></tr><tr><td>List(ruthmoore, hotmail.com)</td></tr><tr><td>List(alexandertyler, gmail.com)</td></tr><tr><td>List(boothashley, hotmail.com)</td></tr><tr><td>List(villajustin, hotmail.com)</td></tr><tr><td>List(vjohnson, montgomery-wilson.com)</td></tr><tr><td>List(brooke60, ferrell.com)</td></tr><tr><td>List(osanchez28, yahoo.com)</td></tr><tr><td>List(david24, donovan.com)</td></tr><tr><td>List(bryan65, smith-choi.com)</td></tr><tr><td>List(sara ...

# %% [markdown]
# ### Collection Functions
#
# Here are some of the built-in functions available for working with arrays.
#
# | Method | Description |
# | --- | --- |
# | array_contains | Returns null if the array is null, true if the array contains value, and false otherwise. |
# | element_at | Returns element of array at given index. Array elements are numbered starting with **1**. |
# | explode | Creates a new row for each element in the given array or map column. |
# | collect_set | Returns a set of objects with duplicate elements eliminated. |

# %%
mattress_df = (details_df
               .filter(array_contains(col("details"), "Mattress"))
               .withColumn("size", element_at(col("details"), 2)))
display(mattress_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>email</th><th>item_name</th><th>details</th><th>size</th></tr></thead><tbody><tr><td>phillipmorgan@hotmail.com</td><td>Standard Queen Mattress</td><td>List(Standard, Queen, Mattress)</td><td>Queen</td></tr><tr><td>derekreed@yahoo.com</td><td>Standard Twin Mattress</td><td>List(Standard, Twin, Mattress)</td><td>Twin</td></tr><tr><td>wbrown@gonzales-miranda.com</td><td>Standard Twin Mattress</td><td>List(Standard, Twin, Mattress)</td><td>Twin</td></tr><tr><td>zavalamario@yahoo.com</td><td>Standard Twin Mattress</td><td>List(Standard, Twin, Mattress)</td><td>Twin</td></tr><tr><td>meganhopkins@gmail.com</td><td>Standard Queen Mattress</td><td>List(Standard, Queen, Mattress)</td><td>Queen</td></tr><tr><td>daniel054@gmail.com</td><td>Standard King Mattress</td><td>List(Standard, King, Mattress)</td><td>King</td></tr><tr><td>hoffmanjohn@chan.com</td><td>Standard King Mattress</td><td>List(Standard, King, Mattress)</td><td>King</td></tr><tr><td>anthony1587@yahoo.com</td><td>Standard Full Mattress</td><td>List(Standard, Full, Mattress)</td><td>Full</td></tr><tr><td>camerontorres@gmail.com</td><td>Standard Queen Mattress</td><td>List(Standard, Queen, Mattress)</td><td>Queen</td></tr><tr><td>camerontorres@gmail.com</td><td>Standard Twin Mattress</td><td>List(Standard, Twin, Mattress)</td><td>Twin</td></tr><tr><td>nicholsjamie@yahoo.com</td><td>Standard King Mattress</td><td>List(Standard, King, Mattress)</td><td>King</td></tr><tr><td>emma43@yahoo.com</td><td>Premium Full Mattress</td><td>List(Premium, Full, Mattress)</td><td>Full</td></tr><tr><td>emma43@yahoo.com</td><td>Standard Queen Mattress</td><td>List(Standard, Queen, Mattress)</td><td>Queen</td></tr><tr><td>josephburke@wilson-brooks.com</td><td>Standard Twin Mattress</td><td>List(Standard, Twin, Mattress)</td><td>Twin</td></tr><tr><td>victor63@gmail.com</td><td>Premium Full Mattress</td><td>List(Premium, Full, Mattress)</td><td>Full</td></tr><tr><td>victor63@gmail.com</td><td>Standard Twin Mattress</td><td>List(Standard, Twin, Mattress)</td><td>Twin</td></tr><tr><td>campbellkatrina@phillips-duarte.com</td><td>Standard Full Mattress</td><td>List(Standard, Full, Mattress)</td><td>Full</td></tr><tr><td>pennyjimenez@patel-jennings.com</td><td>Standard Twin Mattress</td><td>List(Standard, Twin, Mattress)</td><td>Twin</td></tr><tr><td>omichael@gmail.com</td><td>Standard King Mattress</td><td>List(Standard, King, Mattress)</td><td>King</td></tr><tr><td>nelsonsara@yahoo.com</td><td>Standard Queen Mattress</td><td>List(Standard, Queen, Mattress)</td><td>Queen</td></tr><tr><td>kristinwolfe@gmail.com</td><td>Standard Full Mattress</td><td>List(Standard, Full, Mattress)</td><td>Full</td></tr><tr><td>kimberly85@beck.com</td><td>Standard King Mattress</td><td>List(Standard, King, Mattress)</td><td>King</td></tr><tr><td>jennifer93@mooney-stafford.com</td><td>Standard Queen Mattress</td><td>List(Standard, Queen, Mattress)</td><td>Queen</td></tr><tr><td>ericksondesiree@yahoo.com</td><td>Standard Twin Mattress</td><td>List(Standard, Twin, Mattress)</td><td>Twin</td></tr><tr><td>victoranderson@yahoo.com</td><td>Premium King Mattress</td><td>List(Premium, King, Mattress)</td><td>King</td></tr><tr><td>anthony03@yahoo.com</td><td>Standard Full Mattress</td><td>List(Standard, Full, Mattress)</td><td>Full</td></tr><tr><td>michael37@burke.com</td><td>Standard King Mattress</td><td>List(Standard, King, Mattress)</td><td>King</td></tr><tr><td>chelsea99@yahoo.com</td><td>Premium Queen Mattress</td><td>List(Premium, Queen, Mattress)</td><td>Queen</td></tr><tr><td>xfrederick@wilson-conley.net</td><td>Standard Twin Mattress</td><td>List(Standard, Twin, Mattress)</td><td>Twin</td></tr><tr><td>rpeterson65@hotmail.com</td><td>Premium Twin Mattress</td><td>List(Premium, Twin, Mattress)</td><td>Twin</td></tr><tr><td>philip59@yahoo.com</td><td>Standard Twin Mattress</td><td>List(Standard, Twin, Mattr ...

# %% [markdown]
# ### Aggregate Functions
#
# Here are some of the built-in aggregate functions available for creating arrays, typically from GroupedData.
#
# | Method | Description |
# | --- | --- |
# | collect_list | Returns an array consisting of all values within the group. |
# | collect_set | Returns an array consisting of all unique values within the group. |

# %% [markdown]
# Let's say that we wanted to see the sizes of mattresses ordered by each email address. For this, we can use the **`collect_set`** function

# %%
size_df = mattress_df.groupBy("email").agg(collect_set("size").alias("size options"))

display(size_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>email</th><th>size options</th></tr></thead><tbody><tr><td>aadkins@hill.biz</td><td>List(Twin)</td></tr><tr><td>aalexander@hotmail.com</td><td>List(King)</td></tr><tr><td>aallen43@hotmail.com</td><td>List(Queen, Twin)</td></tr><tr><td>aallen@keith-taylor.com</td><td>List(Queen)</td></tr><tr><td>aalvarez4@gmail.com</td><td>List(Queen)</td></tr><tr><td>aalvarez@gmail.com</td><td>List(Queen, Full)</td></tr><tr><td>aanderson12@gmail.com</td><td>List(King)</td></tr><tr><td>aanderson26@hotmail.com</td><td>List(Queen)</td></tr><tr><td>aaron01@hotmail.com</td><td>List(Queen)</td></tr><tr><td>aaron04@wolfe.com</td><td>List(Queen)</td></tr><tr><td>aaron05@hotmail.com</td><td>List(Twin)</td></tr><tr><td>aaron11@mcdonald.com</td><td>List(Full)</td></tr><tr><td>aaron12@yahoo.com</td><td>List(Queen)</td></tr><tr><td>aaron15@daniels.org</td><td>List(Full)</td></tr><tr><td>aaron16@hotmail.com</td><td>List(King)</td></tr><tr><td>aaron196@gmail.com</td><td>List(Twin)</td></tr><tr><td>aaron2097@hotmail.com</td><td>List(Twin)</td></tr><tr><td>aaron46@gmail.com</td><td>List(Queen)</td></tr><tr><td>aaron48@gmail.com</td><td>List(Full)</td></tr><tr><td>aaron48@yahoo.com</td><td>List(Full)</td></tr><tr><td>aaron5765@gmail.com</td><td>List(Queen)</td></tr><tr><td>aaron57@mcconnell-holder.com</td><td>List(Twin)</td></tr><tr><td>aaron57@molina.com</td><td>List(Queen)</td></tr><tr><td>aaron58@hayden.net</td><td>List(Full)</td></tr><tr><td>aaron6364@hotmail.com</td><td>List(Queen)</td></tr><tr><td>aaron6511@gmail.com</td><td>List(Twin)</td></tr><tr><td>aaron6581@yahoo.com</td><td>List(Twin)</td></tr><tr><td>aaron67@rivera.com</td><td>List(Queen)</td></tr><tr><td>aaron74@golden.com</td><td>List(Queen)</td></tr><tr><td>aaron74@hotmail.com</td><td>List(King)</td></tr><tr><td>aaron77@clayton.com</td><td>List(Queen, Twin)</td></tr><tr><td>aaron78@gmail.com</td><td>List(King)</td></tr><tr><td>aaron81@whitehead.net</td><td>List(Full)</td></tr><tr><td>aaron82@garcia-wilson.info</td><td>List(Twin)</td></tr><tr><td>aaron8445@hotmail.com</td><td>List(Twin)</td></tr><tr><td>aaron84@turner-hood.org</td><td>List(Twin)</td></tr><tr><td>aaron86@day.com</td><td>List(Twin)</td></tr><tr><td>aaron87@cobb-smith.com</td><td>List(King)</td></tr><tr><td>aaron8848@gmail.com</td><td>List(King)</td></tr><tr><td>aaron93@robertson.com</td><td>List(Twin)</td></tr><tr><td>aaron940@yahoo.com</td><td>List(Twin)</td></tr><tr><td>aaron951@gmail.com</td><td>List(Queen)</td></tr><tr><td>aaron96@simpson.org</td><td>List(King)</td></tr><tr><td>aaronadams@hotmail.com</td><td>List(King)</td></tr><tr><td>aaronaustin@gmail.com</td><td>List(Twin)</td></tr><tr><td>aaronbarnett@gmail.com</td><td>List(Queen)</td></tr><tr><td>aaroncalhoun@howell-hill.com</td><td>List(Twin)</td></tr><tr><td>aaroncarney@brewer-alexander.org</td><td>List(King)</td></tr><tr><td>aaronclark@guzman.com</td><td>List(Queen)</td></tr><tr><td>aaroncrawford@castillo-zimmerman.net</td><td>List(Full)</td></tr><tr><td>aarondecker@gmail.com</td><td>List(Queen)</td></tr><tr><td>aarondrake@ray.com</td><td>List(Queen)</td></tr><tr><td>aarongarcia@gmail.com</td><td>List(Twin)</td></tr><tr><td>aarongarcia@jones-washington.info</td><td>List(Full)</td></tr><tr><td>aarongreene@parrish.com</td><td>List(Queen, King)</td></tr><tr><td>aarongriffin@frank.info</td><td>List(Full)</td></tr><tr><td>aaronhorton@yahoo.com</td><td>List(Full)</td></tr><tr><td>aaronjohnson@morgan-cohen.com</td><td>List(Queen)</td></tr><tr><td>aaronlittle@gmail.com</td><td>List(King)</td></tr><tr><td>aaronmanning@anderson.net</td><td>List(King)</td></tr><tr><td>aaronmendoza@yahoo.com</td><td>List(Queen)</td></tr><tr><td>aaronmitchell@white-morrow.com</td><td>List(King)</td></tr><tr><td>aaronmorales@rodriguez-wilson.biz</td><td>List(Queen, Full)</td></tr><tr><td>aaronmoses@diaz-cardenas.com</td><td>List(King)</td></tr><tr><td>aaronnelson21@hotmail.com</td><t ...

# %% [markdown]
# ##Union and unionByName
# <img src="https://files.training.databricks.com/images/icon_warn_32.png" alt="Warning"> The DataFrame <a href="https://spark.apache.org/docs/latest/api/python/reference/api/pyspark.sql.DataFrame.union.html" target="_blank">**`union`**</a> method resolves columns by position, as in standard SQL. You should use it only if the two DataFrames have exactly the same schema, including the column order. In contrast, the DataFrame <a href="https://spark.apache.org/docs/latest/api/python/reference/api/pyspark.sql.DataFrame.unionByName.html" target="_blank">**`unionByName`**</a> method resolves columns by name.  This is equivalent to UNION ALL in SQL.  Neither one will remove duplicates.
#
# Below is a check to see if the two dataframes have a matching schema where **`union`** would be appropriate

# %%
mattress_df.schema==size_df.schema
# Out:
# Out[11]: False

# %% [markdown]
# If we do get the two schemas to match with a simple **`select`** statement, then we can use a **`union`**

# %%
union_count = mattress_df.select("email").union(size_df.select("email")).count()

mattress_count = mattress_df.count()
size_count = size_df.count()

mattress_count + size_count == union_count
# Out:
# Out[12]: True

# %% [markdown]
# ### Clean up classroom
#
# And lastly, we'll clean up the classroom.

# %%
DA.cleanup()
# Out:
# Resetting the learning environment...
# ...dropping the database "da_sergio_salgado_4613_asp"...(0 seconds)
# ...removing the working directory "dbfs:/mnt/dbacademy-users/sergio.salgado@n.world/apache-spark-programming-with-databricks"...(0 seconds)
#
# Validating the locally installed datasets...(5 seconds)

# %% [markdown]
# -sandbox
# &copy; 2022 Databricks, Inc. All rights reserved.<br/>
# Apache, Apache Spark, Spark and the Spark logo are trademarks of the <a href="https://www.apache.org/">Apache Software Foundation</a>.<br/>
# <br/>
# <a href="https://databricks.com/privacy-policy">Privacy Policy</a> | <a href="https://databricks.com/terms-of-use">Terms of Use</a> | <a href="https://help.databricks.com/">Support</a>
